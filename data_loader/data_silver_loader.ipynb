# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

lab_path = "dbfs:/Workspace/Users/phamquangduong14112003glhd@gmail.com/bronze_data/bronze_lab_results_from_cardio.csv"

df_lab = spark.read.csv(
    lab_path,
    header=True,
    inferSchema=True
)

df_lab.printSchema()
df_lab.show(5)

# %%
spark.sql("USE CATALOG workspace")
spark.sql("USE SCHEMA health")

df_lab.write.format("delta").mode("overwrite").saveAsTable("bronze_lab_results")
